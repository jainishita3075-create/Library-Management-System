# %%
import pandas as pd
df = pd.read_csv('MOCK_DATA.csv')

# %%
df.head()
# Out:
#    id              name  age  phone number                         email
# 0   1   Windham Morriss   75  943-716-4152  wmorriss0@huffingtonpost.com
# 1   2   Abigale Coathup   49  963-826-3344       acoathup1@csmonitor.com
# 2   3  Marne Gryglewski   59  501-254-8972       mgryglewski2@sbwire.com
# 3   4   Noellyn Alfonzo   41  802-354-0546        nalfonzo3@buzzfeed.com
# 4   5     Ashlie Morley   68  635-741-6910           amorley4@joomla.org

# %%
df['age'].max()
# Out:
# 99

# %%
print(type(["name"]))
# Out:
# <class 'list'>

# %%
print(df.iloc[1,2])
# to read element of an entire row use
# print(df.iloc[1])
# Out:
# 49

# %%
print(df["name"])
# Out:
# 0       Windham Morriss
# 1       Abigale Coathup
# 2      Marne Gryglewski
# 3       Noellyn Alfonzo
# 4         Ashlie Morley
#              ...
# 995     Winne Eglington
# 996        Dredi Napoli
# 997        Lucho Pollok
# 998     Estell Soughton
# 999        Caren Pounds
# Name: name, Length: 1000, dtype: object

# %%
print(df.index[900:920:1])
# Out:
# RangeIndex(start=900, stop=920, step=1)

# %%
print(df[900:920])
# Out:
#       id                  name  age  phone number  \
# 900  901        Clari Hitchens   65  111-273-2549
# 901  902          Rubin Armour   98  915-443-0088
# 902  903           Sela Massel   30  676-743-5531
# 903  904  Florance Silverthorn   39  494-711-3044
# 904  905      Sawyere Windmill   26  249-771-7154
# 905  906        Ragnar Kinavan   88  612-243-8932
# 906  907           Jami Hadley   30  314-353-7995
# 907  908         Aurea Coslett   75  563-784-4176
# 908  909          Ailey Lawtey   93  657-468-5383
# 909  910       Kiersten Hynard   29  582-583-1167
# 910  911   Charmain Kenningley   59  140-881-1746
# 911  912          Misha Dargue   67  181-524-9520
# 912  913       Elisa Usherwood   78  450-653-2540
# 913  914       Maureene Agnolo   60  342-728-0846
# 914  915        Olympie Stores   67  563-504-9988
# 915  916          Romy Peacock   86  667-344-7016
# 916  917         Lauren Gyenes   93  531-712-7688
# 917  918       Hermie Brownlie   44  904-903-1744
# ...
