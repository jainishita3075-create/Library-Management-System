# %%
f=open('new.txt')
f.read()
# Out:
# 'Hey there!\nThis is a trial file for python File Handling Concepts.'

# %%
f=open('new.txt','w')
f.write("Learning something new.")
f.close()

# %%
f=open('new.txt')
f.read()
# Out:
# 'Learning something new.'

# %%
f=open('new.txt','a')
f.write("practice for it")
f.close()

# %%
f=open('new.txt')
f.read()
# Out:
# 'Learning something new.practice for it'

# %%
f = open("new.txt", "x")
f.close()
print("File created")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 f = open("new.txt", "x")
#       2 f.close()
#       3 print("File created")
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileExistsError: [Errno 17] File exists: 'new.txt'

# %%
f = open("notes.txt", "x")
f.close()
print("File created")
# Out:
# File created

# %%
f = open("notes.txt", "rb")
data = f.read()

print(data)
f.close()
# Out:
# b''

# %%
f = open("new.txt", "rb")
data = f.read()

print(data)
f.close()
# Out:
# b'Learning something new.practice for it'

# %%
f = open("new.txt", "r")
print("Filename:", f.name)
print("Mode:", f.mode)
print("Is Closed?", f.closed)

f.close()
print("Is Closed?", f.closed)
# Out:
# Filename: new.txt
# Mode: r
# Is Closed? False
# Is Closed? True

# %%
with open("example.txt", "w") as file:
    file.write("Hello, Python!")

# %%
with open("example.txt", "r") as file:
    data = file.read()
    print(data)
# Out:
# Hello, Python!

# %%
with open('example.txt', 'rb') as file:
    data = file.read()
    # Process the binary data
